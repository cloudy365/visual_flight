# %%
# %matplotlib notebook
from flight_show3d import show3d_flight

# %%
show3d_flight('RF02_Time_Lat_Lon_Alt.xlsx', stride=10, llcrnrlon=115, llcrnrlat=12, urcrnrlon=125, urcrnrlat=20)
# Out:
# <img src="data:image/png;base64,..." width="1200">
